# %% [markdown]
# طبق اینکه گفته بودن از روی جاوا برداشتن
#
# Maven Directory Structure in jave :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# از روی پروژه های گذشته
#
# projectdir
#   - metadata
#     - uml
#       - classDiagram
#       - databases
#
#     - issues
#
#   - resources
#     - main
#       - x
#
#     - test
#       - x
#
#   - .data
#
#   - src
#     - main
#       - x
#
#     - test
#       - x
#
#
#   - pyproject.toml
#   - poetry.lock
#   - .gitignore
#
#
# ** x :
#   - group project name
#     - project name
#       - ...
#       - ...
#
#
#
# *metadata :*
#
# *resources :*
#
# *.data :*
